# %%
import pandas as pd
data={
    "name": ["sagar","Alyssa","Praful"],
    "age":[25,2382,34],
    "city": ["Patna",'Mumbai','Nagpur']
}

# %%
print(data)
df = pd.DataFrame(data)
print(df)
# Out:
# {'name': ['sagar', 'Alyssa', 'Praful'], 'age': [25, 2382, 34], 'city': ['Patna', 'Mumbai', 'Nagpur']}
#      name   age    city
# 0   sagar    25   Patna
# 1  Alyssa  2382  Mumbai
# 2  Praful    34  Nagpur

# %%
# To save datframe into files

df.to_csv("output_csv.csv",index=False) #index false to remove the indexing
df.to_excel("output_excel.xlsx",index=False) 
df.to_json("output_json.json",index=False)

# %%
# to read files
df = pd.read_csv("output_csv.csv")
print(df,"\n")
df = pd.read_excel("output_excel.xlsx")
print(df,"\n")
df = pd.read_json("output_json.json")
print(df,"\n")
# Out:
#      name   age    city
# 0   sagar    25   Patna
# 1  Alyssa  2382  Mumbai
# 2  Praful    34  Nagpur
#
#      name   age    city
# 0   sagar    25   Patna
# 1  Alyssa  2382  Mumbai
# 2  Praful    34  Nagpur
#
#      name   age    city
# 0   sagar    25   Patna
# 1  Alyssa  2382  Mumbai
# 2  Praful    34  Nagpur
